# %% [markdown]
# Find the markdown blocks that say interaction required! The notebook should take care of the rest!

# %% [markdown]
# # Import libs

# %%
import sys
import os
sys.path.append('..')
from eflow.foundation import DataPipeline,DataFrameTypes
from eflow.model_analysis import ClassificationAnalysis
from eflow.utils.modeling_utils import optimize_model_grid
from eflow.utils.eflow_utils import get_type_holder_from_pipeline, remove_unconnected_pipeline_segments
from eflow.utils.pandas_utils import data_types_table
from eflow.auto_modeler import AutoCluster
from eflow.data_pipeline_segments import DataEncoder

import pandas as pd
import numpy as np
import scikitplot as skplt
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
import copy
import pickle
from IPython.display import clear_output

# %%
# # Additional add ons
# !pip install pandasgui
# !pip install pivottablejs
# clear_output()

# %%
# %matplotlib notebook
# %matplotlib inline

# %% [markdown]
# ## Declare Project Variables

# %% [markdown]
# ### Interaction required

# %%
dataset_path = ""

# -----
dataset_name = ""
pipeline_name = ""

# -----


# -----
notebook_mode = True

# %% [markdown]
# ## Clean out segment space

# %%
remove_unconnected_pipeline_segments()

# %% [markdown]
# # Import dataset

# %%
df = pd.read_csv(dataset_path)
shape_df = pd.DataFrame.from_dict({'Rows': [df.shape[0]],
                                   'Columns': [df.shape[1]]})
display(shape_df)
display(df.head(30))
# Out:
#    Rows  Columns
# 0   891       12
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# 26           27         0       3
# 27           28         0       1
# 28           29         1       3
# 29           30         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                               Rice, Master. Eugene    male   2.0      4
# 17                       Williams, Mr. Charles Eugene    male   NaN      0
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                            Masselmani, Mrs. Fatima  female   NaN      0
# 20                               Fynney, Mr. Joseph J    male  35.0      0
# 21                              Beesley, Mr. Lawrence    male  34.0      0
# 22                        McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
# 24                      Palsson, Miss. Torborg Danira  female   8.0      3
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 26                            Emir, Mr. Farred Chehab    male   NaN      0
# 27                     Fortune, Mr. Charles Alexander    male  19.0      3
# 28                      O'Dwyer, Miss. Ellen "Nellie"  female   NaN      0
# 29                                Todoroff, Mr. Lalio    male   NaN      0
#
#     Parch            Ticket      Fare        Cabin Embarked
# 0       0         A/5 21171    7.2500          NaN        S
# 1       0          PC 17599   71.2833          C85        C
# 2       0  STON/O2. 3101282    7.9250          NaN        S
# 3       0            113803   53.1000         C123        S
# 4       0            373450    8.0500          NaN        S
# 5       0            330877    8.4583          NaN        Q
# 6       0             17463   51.8625          E46        S
# 7       1            349909   21.0750          NaN        S
# 8       2            347742   11.1333          NaN        S
# 9       0            237736   30.0708          NaN        C
# 10      1           PP 9549   16.7000           G6        S
# 11      0            113783   26.5500         C103        S
# 12      0         A/5. 2151    8.0500          NaN        S
# 13      5            347082   31.2750          NaN        S
# 14      0            350406    7.8542          NaN        S
# 15      0            248706   16.0000          NaN        S
# 16      1            382652   29.1250          NaN        Q
# 17      0            244373   13.0000          NaN        S
# 18      0            345763   18.0000          NaN        S
# 19      0              2649    7.2250          NaN        C
# 20      0            239865   26.0000          NaN        S
# 21      0            248698   13.0000          D56        S
# 22      0            330923    8.0292          NaN        Q
# 23      0            113788   35.5000           A6        S
# 24      1            349909   21.0750          NaN        S
# 25      5            347077   31.3875          NaN        S
# 26      0              2631    7.2250          NaN        C
# 27      2             19950  263.0000  C23 C25 C27        S
# 28      0            330959    7.8792          NaN        Q
# 29      0            349216    7.8958          NaN        S

# %%
data_types_table(df)
# Out:
#             Data Types
# Features
# Age            float64
# Fare           float64
# PassengerId      int64
# Survived         int64
# Pclass           int64
# SibSp            int64
# Parch            int64
# Name            object
# Sex             object
# Ticket          object
# Cabin           object
# Embarked        object

# %% [markdown]
# # Loading and init df_features

# %%
# Option: 1
# df_features = get_type_holder_from_pipeline(pipeline_name)

# %%
# Option: 2
df_features = DataFrameTypes()
df_features.init_on_json_file(os.getcwd() + f"/eflow Data/{dataset_name}/df_features.json")

# %%
df_features.display_features(display_dataframes=True,
                             notebook_mode=notebook_mode)
# Out:
#          Data Types
# Features
# Embarked     string
# Cabin        string
# Sex          string
# Pclass       string
# Survived       bool
# Parch       integer
# SibSp       integer
# Fare          float
# Age           float

# %%
qualtative_features = df_features.string_features() | df_features.categorical_features()
qualtative_features
# Out:
# {'Cabin', 'Embarked', 'Pclass', 'Sex'}

# %% [markdown]
# # Any extra processing before eflow DataPipeline

# %% [markdown]
# # Setup pipeline structure

# %% [markdown]
# ### Interaction Required

# %%
main_pipe = DataPipeline(pipeline_name,
                         df,
                         df_features)
# Out:
# The file 'root_pipeline.json' exist!
# Now configuring object with proper pipeline segments...
# Removing the feature: "Name"
# Removing the feature: "PassengerId"
# Removing the feature: "Ticket"

# %%
main_pipe.perform_pipeline(df,
                           df_features)
# Out:
# Ignore feature:  Fare

# %%
df
# Out:
#      Survived        Age  SibSp  Parch     Fare  Sex_female  Sex_male  \
# 0           0  22.000000      1      0   7.2500       False      True
# 1           1  38.000000      1      0  71.2833        True     False
# 2           1  26.000000      0      0   7.9250        True     False
# 3           1  35.000000      1      0  53.1000        True     False
# 4           0  35.000000      0      0   8.0500       False      True
# ..        ...        ...    ...    ...      ...         ...       ...
# 886         0  27.000000      0      0  13.0000       False      True
# 887         1  19.000000      0      0  30.0000        True     False
# 888         0  29.444268      1      2  23.4500        True     False
# 889         1  26.000000      0      0  30.0000       False      True
# 890         0  32.000000      0      0   7.7500       False      True
#
#      Pclass_1  Pclass_2  Pclass_3  Embarked_Cherbourg  Embarked_Queenstown  \
# 0       False     False      True               False                False
# 1        True     False     False                True                False
# 2       False     False      True               False                False
# 3        True     False     False               False                False
# 4       False     False      True               False                False
# ..        ...       ...       ...                 ...                  ...
# 886     False      True     False               False                False
# 887      True     False     False               False                False
# 888     False     False      True               False                False
# 889      True     False     False                True                False
# 890     False     False      True               False                 True
#
#      Embarked_Southampton
# 0                    True
# 1                   False
# 2                    True
# 3                    True
# 4                    True
# ..                    ...
# 886                  True
# 887                  True
# 888                  True
# 889                 False
# 890                 False
#
# [891 rows x 13 columns]

# %% [markdown]
# # Generate clustering models with automodeler

# %%
auto_cluster = AutoCluster(df,
                           df_features,
                           project_sub_dir=dataset_name,
                           overwrite_full_path=None,
                           notebook_mode=True,
                           pca_perc=.8)
# Out:
# Inspecting scaled results!
#                               Mean  Standard Dev
# Survived              3.987333e-17           1.0
# Age                   1.594933e-16           1.0
# SibSp                 4.386066e-17           1.0
# Parch                 5.382900e-17           1.0
# Fare                  3.987333e-18           1.0
# Sex_female            3.987333e-17           1.0
# Sex_male             -1.156327e-16           1.0
# Pclass_1             -7.575933e-17           1.0
# Pclass_2              1.993666e-17           1.0
# Pclass_3             -6.778466e-17           1.0
# Embarked_Cherbourg   -1.993666e-17           1.0
# Embarked_Queenstown   0.000000e+00           1.0
# Embarked_Southampton -8.373399e-17           1.0
# Inspecting applied scaler and pca results!
#                         Mean  Standard Dev
# PCA_Feature_1   5.980999e-17  1.755406e+00
# PCA_Feature_2  -3.189866e-17  1.473500e+00
# PCA_Feature_3   8.572766e-17  1.403483e+00
# PCA_Feature_4  -2.392400e-17  1.237023e+00
# PCA_Feature_5  -5.582266e-17  1.063722e+00
# PCA_Feature_6   7.974666e-18  9.749387e-01
# PCA_Feature_7   9.768966e-17  8.667995e-01
# PCA_Feature_8   5.980999e-18  7.509349e-01
# PCA_Feature_9   4.984166e-17  6.864391e-01
# PCA_Feature_10 -1.036707e-16  6.155528e-01
# PCA_Feature_11  3.550002e-17  3.582431e-16
# PCA_Feature_12  2.289575e-17  1.739693e-16
# PCA_Feature_13 -4.791364e-17  1.136330e-16
# After applying pca with a cutoff percentage 0.8% for the cumulative index. Using features 1 to 6
# Old shape (891, 13)
# New shape (891, 6)
#
# Inspecting data after final scaler applied!
#                        Mean  Standard Dev
# PCA_Feature_1  7.974666e-18           1.0
# PCA_Feature_2 -2.392400e-17           1.0
# PCA_Feature_3  1.395567e-17           1.0
# PCA_Feature_4 -1.196200e-17           1.0
# PCA_Feature_5 -7.974666e-18           1.0
# PCA_Feature_6  7.974666e-18           1.0

# %% [markdown]
# ### Temporialy remove dataframe to save RAM for processing

# %%
del df

# %% [markdown]
# # Inspect Hierarchical models

# %%
auto_cluster.visualize_hierarchical_clustering()
# Out:
# Creating graphic for Hierarchical Clustering Method: complete...
# Creating graphic for Hierarchical Clustering Method: single...
# Creating graphic for Hierarchical Clustering Method: weighted...
# Creating graphic for Hierarchical Clustering Method: ward...
# Creating graphic for Hierarchical Clustering Method: average...
# Creating graphic for Hierarchical Clustering Method: centroid...
# Creating graphic for Hierarchical Clustering Method: median...
# [4, 5, 7, 8, 8, 9, 13]

# %%
auto_cluster.create_elbow_models(repeat_operation=10,
                                 max_k_value=15,
                                 display_visuals=True)
# Out:
# K-Means Elbow Seq Count 1: 100%|██████████| 15/15 [00:01<00:00, 14.81it/s, model_count=15]
# K-Means Elbow Seq Count 2: 100%|██████████| 15/15 [00:01<00:00, 14.41it/s, model_count=15]
# K-Means Elbow Seq Count 3: 100%|██████████| 15/15 [00:01<00:00, 13.89it/s, model_count=15]
# K-Means Elbow Seq Count 4: 100%|██████████| 15/15 [00:01<00:00, 14.46it/s, model_count=15]
# K-Means Elbow Seq Count 5: 100%|██████████| 15/15 [00:00<00:00, 15.68it/s, model_count=15]
# K-Means Elbow Seq Count 6: 100%|██████████| 15/15 [00:01<00:00, 14.77it/s, model_count=15]
# K-Means Elbow Seq Count 7: 100%|██████████| 15/15 [00:01<00:00, 14.30it/s, model_count=15]
# K-Means Elbow Seq Count 8: 100%|██████████| 15/15 [00:01<00:00, 14.48it/s, model_count=15]
# K-Means Elbow Seq Count 9: 100%|██████████| 15/15 [00:00<00:00, 15.58it/s, model_count=15]
# K-Means Elbow Seq Count 10: 100%|██████████| 15/15 [00:01<00:00, 14.53it/s, model_count=15]
#   Proximity Knees  Counts
# 1               7       9
# 2               8       7
# 0               6       6
# 4               9       4
# 3               5       3
# 5               4       1
#   Main Knees  Counts
# 2          8       4
# 0          7       3
# 1          6       2
# 3          5       1
# Fuzzy C-means Elbow Seq Count 1: 100%|██████████| 15/15 [00:01<00:00, 10.30it/s, model_count=15]
# Fuzzy C-means Elbow Seq Count 2: 100%|██████████| 15/15 [00:01<00:00, 10.49it/s, model_count=15]
# Fuzzy C-means Elbow Seq Count 3: 100%|██████████| 15/15 [00:01<00:00, 10.23it/s, model_count=15]
# Fuzzy C-means Elbow Seq Count 4: 100%|██████████| 15/15 [00:01<00:00,  9.78it/s, model_count=15]
# Fuzzy C-means Elbow Seq Count 5: 100%|██████████| 15/15 [00:01<00:00,  9.86it/s, model_count=15]
# Fuzzy C-means Elbow Seq Count 6: 100%|██████████| 15/15 [00:01<00:00, 10.09it/s, model_count=15]
# Fuzzy C-means Elbow Seq Count 7: 100%|██████████| 15/15 [00:01<00:00, 10.01it/s, model_count=15]
# Fuzzy C-means Elbow Seq Count 8: 100%|██████████| 15/15 [00:01<00:00,  9.74it/s, model_count=15]
# Fuzzy C-means Elbow Seq Count 9: 100%|██████████| 15/15 [00:01<00:00,  9.97it/s, model_count=15]
# Fuzzy C-means Elbow Seq Count 10: 100%|██████████| 15/15 [00:01<00:00,  8.79it/s, model_count=15]
#   Proximity Knees  Counts
# 2               3       5
# 3               6       5
# 4               7       5
# 5               8       5
# 0               1       3
# 1               2       3
# 6               4       2
# 7               5       2
#   Main Knees  Counts
# 1          7       5
# 0          2       3
# 2          4       2
# K-Medoids Elbow Seq Count 1: 100%|██████████| 15/15 [00:01<00:00, 13.22it/s, model_count=15]
# K-Medoids Elbow Seq Count 2: 100%|██████████| 15/15 [00:01<00:00, 12.83it/s, model_count=15]
# K-Medoids Elbow Seq Count 3: 100%|██████████| 15/15 [00:01<00:00, 13.40it/s, model_count=15]
# K-Medoids Elbow Seq Count 4: 100%|██████████| 15/15 [00:01<00:00, 12.79it/s, model_count=15]
# K-Medoids Elbow Seq Count 5: 100%|██████████| 15/15 [00:01<00:00, 13.32it/s, model_count=15]
# K-Medoids Elbow Seq Count 6: 100%|██████████| 15/15 [00:01<00:00, 13.12it/s, model_count=15]
# K-Medoids Elbow Seq Count 7: 100%|██████████| 15/15 [00:01<00:00, 13.44it/s, model_count=15]
# K-Medoids Elbow Seq Count 8: 100%|██████████| 15/15 [00:01<00:00, 13.50it/s, model_count=15]
# K-Medoids Elbow Seq Count 9: 100%|██████████| 15/15 [00:01<00:00, 13.60it/s, model_count=15]
# K-Medoids Elbow Seq Count 10: 100%|██████████| 15/15 [00:01<00:00, 13.79it/s, model_count=15]
# Something went wrong when trying to save the model: K-Medoids
# Something went wrong when trying to save the model: K-Medoids
# Something went wrong when trying to save the model: K-Medoids
#   Proximity Knees  Counts
# 0               7       7
# 5               6       6
# 1               8       5
# 4               5       5
# 2               9       3
# 3               4       2
# 6              10       1
# 7               3       1
#   Main Knees  Counts
# 3          6       3
# 0          8       2
# 4          7       2
# 1          5       1
# 2          9       1
# 5          4       1
# Somsc Elbow Seq Count 1: 100%|██████████| 15/15 [00:01<00:00, 13.76it/s, model_count=15]
#   Proximity Knees  Counts
# 0               5       1
# 1               6       1
# 2               7       1
#   Main Knees  Counts
# 0          6       1
# K-Medians Elbow Seq Count 1: 100%|██████████| 15/15 [00:01<00:00,  9.29it/s, model_count=15]
# K-Medians Elbow Seq Count 2: 100%|██████████| 15/15 [00:01<00:00, 10.22it/s, model_count=15]
# K-Medians Elbow Seq Count 3: 100%|██████████| 15/15 [00:01<00:00,  9.96it/s, model_count=15]
# K-Medians Elbow Seq Count 4: 100%|██████████| 15/15 [00:01<00:00, 10.38it/s, model_count=15]
# K-Medians Elbow Seq Count 5: 100%|██████████| 15/15 [00:01<00:00, 10.89it/s, model_count=15]
# K-Medians Elbow Seq Count 6: 100%|██████████| 15/15 [00:01<00:00, 10.35it/s, model_count=15]
# K-Medians Elbow Seq Count 7: 100%|██████████| 15/15 [00:01<00:00, 10.23it/s, model_count=15]
# K-Medians Elbow Seq Count 8: 100%|██████████| 15/15 [00:01<00:00, 10.32it/s, model_count=15]
# K-Medians Elbow Seq Count 9: 100%|██████████| 15/15 [00:01<00:00, 10.96it/s, model_count=15]
# K-Medians Elbow Seq Count 10: 100%|██████████| 15/15 [00:01<00:00, 10.33it/s, model_count=15]
#   Proximity Knees  Counts
# 1               4       6
# 2               5       6
# 4               7       4
# 5               8       4
# 6               9       4
# 0               3       3
# 3               6       3
#   Main Knees  Counts
# 2          8       4
# 0          4       3
# 1          5       3
# Cure Elbow Seq Count 1: 100%|██████████| 15/15 [00:01<00:00,  9.38it/s, model_count=15]
#   Proximity Knees  Counts
# 0               2       1
# 1               3       1
# 2               4       1
#   Main Knees  Counts
# 0          3       1
# [2, 3, 4]

# %%
raise ValueError("Testing")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-1553ef5379e2> in <module>
# ----> 1 raise ValueError("Testing")
#
# ValueError: Testing

# %%
df = pd.read_csv(dataset_path)
df

# %%
df_features.init_on_json_file(os.getcwd() + f"/eflow Data/{dataset_name}/df_features.json")
df_features.display_features(display_dataframes=True,
                             notebook_mode=notebook_mode)

# %%
main_pipe.perform_pipeline(df,
                           df_features)

# %%
df

# %%
data_encoder = DataEncoder(create_file=False)

# %%
data_encoder.revert_dummies(df,
                            df_features,
                            qualtative_features=df_features.get_dummy_encoded_features().keys())

# %%
df
