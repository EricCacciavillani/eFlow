# %%
import sys
import pandas as pd
sys.path.append('..')

from Libraries.Utils.Global_Utils import *
from Libraries.ClusterMaster import *
from Libraries.DataframeTypeHolder import *
from Libraries.DataAnalysis import *
# %matplotlib inline

# %%
df = pd.read_csv("Datasets/Video_Games_Sales_as_at_22_Dec_2016.csv")
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 1           NaN        NaN         NaN       NaN    NaN
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 4           NaN        NaN         NaN       NaN    NaN

# %%
df["Year_of_Release"].dropna(inplace=True)

# %%
df_features = DataframeTypeHolder(df)
# Out:
# Categorical Features: {'Name', 'User_Score', 'Publisher', 'Rating', 'Platform', 'Genre', 'Developer'}
#
# Possible One hot encoded feature names: {'Name': ["Name_The_Legend_of_Zelda:_Majora's_Mask_3D", 'Name_Montessori_Music', 'Name_Klonoa', 'Name_Harry_Potter_and_the_Prisoner_of_Azkaban', 'Name_Metal_Gear_Ac!d', 'Name_Micro_Machines', "Name_Wayne_Gretzky's_3D_Hockey", 'Name_Bloody_Roar', 'Name_The_Sims:_Vacation', 'Name_Wand_of_Fortune', 'Name_Commando', 'Name_J-League_Pro_Soccer_Club_o_Tsukurou!_6:_Pride_of_J', 'Name_Snoopy_vs_the_Red_Baron', 'Name_Atelier_Firis:_The_Alchemist_of_the_Mysterious_Journey', 'Name_Nogizaka_Haruka_no_Himitsu_Cosplay,_Hajime_Mashita', 'Name_MotorStorm', 'Name_MiniCopter:_Adventure_Flight', 'Name_Mystery_Trackers:_The_Void', 'Name_Sins_of_a_Solar_Empire:_Trinity', 'Name_Style_Lab:_Makeover', 'Name_F-Zero_X', 'Name_Oreshika:_Tainted_Bloodlines', 'Name_Countdown:_The_Game', 'Name_Michael_Phelps:_Push_the_Limit', 'Name_Forbidden_Siren_2', 'Name_Wizardry:_Tale_of_the_Forsaken_Land', 'Name_Root_Infinity_Rexx', 'Name_Primal_Rage', "Name_Disney's_Chip_'n_Dale:_Rescue_Rangers", 'Name_Independence_Day', 'Name_Utawarerumono_Portable', 'Name_A_Collection_of_Classic_Games_from_the_Intellivision', 'Name_The_Legend_of_Zelda', 'Name_Mia_Hamm_Soccer_64', 'Name_Silhouette_Mirage', 'Name_Pokémon_Platinum_Version', 'Name_World_Championship_Poker:_Featuring_Howard_Lederer_-_All_In', "Name_A.C.E.:_Another_Century's_Episode", 'Name_Atlantis', 'Name_Maken_Shao:_Demon_Sword', 'Name_Mercury_Meltdown_Revolution', 'Name_Derby_Stallion_64', 'Name_Robo_Pit', 'Name_Mind_over_Matter', 'Name_PachiPara_3D:_Ooumi_Monogatari_2_-_Pachi_Pro_Fuuunroku_Hana', 'Name_3_in_1:_Solitaire,_Mahjong_&_Tangram', 'Name_Magical_Vacation', 'Name_Pokemon_Rumble_World', 'Name_Transformer:_Rise_of_the_Dark_Spark_(3DS)', 'Name_Otona_no_Renai_Shousetsu:_Harlequin_Selection', 'Name_Emily_Archer_and_the_Curse_of_Tutankhamun', 'Name_ECW_Hardcore_Revolution', 'Name_Action_Man-Operation_Extreme', 'Name_SD_Gundam_Force', 'Name_Face_Training', 'Name_Star_Ocean:_The_Last_Hope_International', 'Name_Aidyn_Chronicles:_The_First_Mage', "Name_Dexter's_Lab_Chess_Challenge", 'Name_Negima!?_3-Jikanme_~Koi_to_Mahou_to_Sekaiju_Densetsu~', 'Name_L:_the_proLogue_to_DEATH_NOTE_-_Rasen_no_Wana', 'Name_Hamster_Club_4:_Shigessa_Daidassou', 'Name_Build-A-Bear_Workshop', 'Name_Minna_no_Golf_Jou_Vol.1', 'Name_SoulCalibur_IV', 'Name_Baten_Kaitos:_Eternal_Wings_and_the_Lost_Ocean', "Name_World_Cup_'98_France:_Road_to_Win", 'Name_Here_They_Lie', 'Name_The_Guided_Fate_Paradox', 'Name_The_Legend_of_Spyro:_A_New_Beginning', 'Name_Polarium', 'Name_Urakata_Hakuoki', 'Name_Star_Trek:_The_Game', 'Name_Uprising_X', 'Name_Miyako:_Awayuki_no_Utage', 'Name_Twisted_Metal', 'Name_Paranormal_Pursuit:_The_Gifted_One', 'Name_Mystery_Case_Files:_Ravenhearst', 'Name_Metroid:_Other_M', 'Name_Shining_Blade', 'Name_Yu-Gi-Oh!_World_Championship_2007', "Name_Konami_Collector's_Series:_Arcade_Advanced", 'Name_Danny_Phantom:_Urban_Jungle', 'Name_NBA_Live_2000', 'Name_Unchained_Blades_', 'Name_Sakura_Taisen_2_-_Kimi,_Shinitamou_Koto_Nakare', "Name_Hammerin'_Hero", 'Name_Demon_Attack', 'Name_World_of_Outlaws:_Sprint_Cars_2002', 'Name_Summon_Night:_Twin_Age', 'Name_Duel_Masters', 'Name_Ninja_Reflex', 'Name_WWE_2K14', 'Name_Marble_Madness_/_Klax', "Name_Build_'n_Race", 'Name_Elminage_Original:_Majo_to_Megami_to_Kamigami_no_Yubiwa', 'Name_Elven_Legacy', 'Name_The_Operative:_No_One_Lives_Forever', 'Name_Eternal_Poison_(JP_sales)', 'Name_Holy_Invasion_of_Privacy,_Badman!_What_Did_I_Do_to_Deserve_This?', 'Name_Test_Drive_Unlimited_2', 'Name_Emblem_of_Gundam', 'Name_Disgaea_5:_Alliance_of_Vengeance', 'Name_Tiger_Woods_PGA_Tour_Golf', 'Name_Jet_Grind_Radio', 'Name_Cool_Boarders_2', 'Name_Mario_Super_Sluggers', 'Name_MegaTagmension_Blanc_+_Neptune_VS_Zombies', 'Name_Final_Fantasy_II_Anniversary_Edition', 'Name_Shirogane_no_Soleil:_Contract_to_the_Future_-_Mirai_e_no_Keiyaku', 'Name_Makai_Senki_Disgaea_4:_Fuuka_&_Desco-hen_Hajime_Mashita', 'Name_Power_Pro_Success_Legends', 'Name_Puyo_Puyo_Sun', 'Name_Crush', 'Name_Sunny_Ga ...
#
# ------------------------------------------------------------------------------------------
# Numerical Features: {'User_Count', 'JP_Sales', 'Critic_Count', 'Critic_Score', 'Global_Sales', 'EU_Sales', 'Year_of_Release', 'Other_Sales', 'NA_Sales'}
#
# Float Features: {'User_Count', 'JP_Sales', 'Critic_Count', 'Critic_Score', 'Global_Sales', 'EU_Sales', 'Year_of_Release', 'Other_Sales', 'NA_Sales'}

# %%
DataAnalysis(df,
             df_features)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-dfc93987a0d4> in <module>
#       1 DataAnalysis(df,
# ----> 2              df_features)
#
# ~/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/Master_Universal_Data_Analytics/Libraries/DataAnalysis.py in __init__(self, df, df_features)
#      14         self.__PROJECT = enum(
#      15             PATH_TO_OUTPUT_FOLDER=''.join(
# ---> 16                 os.getcwd().partition('/Libraries')[0:1]) + output_fig_sub_dir)
#      17
#      18         if df.isnull().values.any():
#
# NameError: name 'os' is not defined
