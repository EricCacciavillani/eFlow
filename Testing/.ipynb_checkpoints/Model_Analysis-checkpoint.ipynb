# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
import sys

sys.path.append('..')
from Libraries.Utils.Global_Utils import *
from Libraries.ClusterMaster import *
from Libraries.DataframeTypeHolder import *
from Libraries.DataAnalysis import *
from xgboost import XGBClassifier

# %% [markdown]
# # Set-Up Phase

# %% [markdown]
# ## Import titanic dataset

# %%
df = pd.read_csv("Datasets/titanic_train.csv")
display(df.shape)
df.head()
# Out:
# (891, 12)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df["Survived"] = df["Survived"].astype(bool)
df["Survived"].value_counts()
# Out:
# False    549
# True     342
# Name: Survived, dtype: int64

# %% [markdown]
# ## Remove Un-Wanted Columns

# %%
df.drop(columns=['Name',"Ticket"],
        inplace=True)
df.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# 0            1     False       3    male  22.0      1      0   7.2500   NaN
# 1            2      True       1  female  38.0      1      0  71.2833   C85
# 2            3      True       3  female  26.0      0      0   7.9250   NaN
# 3            4      True       1  female  35.0      1      0  53.1000  C123
# 4            5     False       3    male  35.0      0      0   8.0500   NaN
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %% [markdown]
# ## Change cabin column to have the level on the ship

# %%
df["Cabin"] = df["Cabin"].str.replace(r'\d+', '').str[0]
df["Cabin"].value_counts()
# Out:
# C    59
# B    47
# D    33
# E    32
# A    15
# F    13
# G     4
# T     1
# Name: Cabin, dtype: int64

# %%
df_features = DataframeTypeHolder(df,
                                  target_col="Sex")
# Out:
# Categorical Features: {'Sex', 'Cabin', 'Embarked'}
#
# Bool Features: {'Survived'}
#
# Possible One hot encoded feature names: {'Sex': ['Sex_male', 'Sex_female'], 'Cabin': ['Cabin_F', 'Cabin_T', 'Cabin_E', 'Cabin_D', 'Cabin_A', 'Cabin_B', 'Cabin_C', 'Cabin_G'], 'Embarked': ['Embarked_Q', 'Embarked_S', 'Embarked_C']}
#
# ------------------------------------------------------------------------------------------
# Numerical Features: {'Age', 'Parch', 'Pclass', 'Fare', 'SibSp', 'PassengerId'}
#
# Integer Features: {'Parch', 'Pclass', 'SibSp', 'PassengerId'}
#
# Float Features: {'Age', 'Fare'}
#
# Target Feature: Sex

# %%
analysis_obj = DataAnalysis(df,
                            df_features)
# Out:
# PassengerId      int64
# Survived          bool
# Pclass           int64
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object
# Your selected dataframe has 10 columns.
# There are 3 columns that have missing values.
#           Missing Values  % of Total Values
# Cabin                687               77.1
# Age                  177               19.9
# Embarked               2                0.2
# ********************************************************************************

# %%
df.drop(columns=["Cabin"],
        inplace=True)

# %%
df_features = DataframeTypeHolder(df,
                                  target_col="Survived")
# Out:
# Categorical Features: {'Sex', 'Embarked'}
#
# Bool Features: {'Survived'}
#
# Possible One hot encoded feature names: {'Sex': ['Sex_male', 'Sex_female'], 'Embarked': ['Embarked_Q', 'Embarked_S', 'Embarked_C']}
#
# ------------------------------------------------------------------------------------------
# Numerical Features: {'Age', 'Parch', 'Pclass', 'Fare', 'SibSp', 'PassengerId'}
#
# Integer Features: {'Parch', 'Pclass', 'SibSp', 'PassengerId'}
#
# Float Features: {'Age', 'Fare'}
#
# Target Feature: Survived

# %%
df_features.get_all_features()
# Out:
# ['Pclass',
#  'Survived',
#  'SibSp',
#  'Age',
#  'Parch',
#  'Sex',
#  'Embarked',
#  'Fare',
#  'PassengerId']

# %%
# %matplotlib notebook
# %matplotlib inline

# %%
import pygal
from IPython.display import SVG
for feature_col in df_features.get_categorical_features():
    
    pie_chart = pygal.Pie()
    pie_chart.title = 'Titanic Dataset: {0}'.format(feature_col)
    
    for feature_val in set(df[feature_col].values): 
        pie_chart.add(str(feature_val), sum(df[feature_col] == feature_val))
    display(SVG(pie_chart.render()))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-1690b3d0de12> in <module>
# ----> 1 import pygal
#       2 from IPython.display import SVG
#       3 for feature_col in df_features.get_categorical_features():
#       4
#       5     pie_chart = pygal.Pie()
#
# ModuleNotFoundError: No module named 'pygal'

# %%
df, le_map = encode_df(df,
                       df_features)
df.head()

# %%
DataAnalysis(df)

# %%
df[df_features.get_target()].value_counts()

# %%
print_encoder_map(le_map)

# %%
X = np.array(df.drop(df_features.get_target(),
                     axis=1,
                     inplace=False))
y = np.array(df[df_features.get_target()])

X_train, X_test, y_train, y_test = train_test_split(X,y,
                                                    test_size=0.30,
                                                    random_state=42,
                                                    stratify=y)
X = None
y = None

# %%
display(X_train.shape)
display(y_train.shape)
display(y_test.shape)
display(X_test.shape)

# %%
params = {
    'objective':['binary:logistic'],
    'learning_rate':[.001,.01,.1,.15],
    'min_child_weight': [5,6,7,8,9,10],
    'gamma': [.15,.2,.1,.05,.01,.2,.25,.3],
    'subsample': [0.1,0.2,.05,.15,.02,.01],
    'colsample_bytree': [0.6,0.2,0.1,.05],
    'max_depth': [2,3,4,5,6,7],
    'n_estimators': [50,100,200,300,500,600,700],
}
best_xgb,xgb_best_parms = optimize_model_grid(
    model=XGBClassifier(),
    X_train=X_train,
    y_train=y_train,
    cv=5,
    param_grid=params,
    n_jobs=9,
)

# %%
# Tuned Parameters: {'colsample_bytree': 0.6, 'gamma': 0.15, 'learning_rate': 0.001, 'max_depth': 2, 'min_child_weight': 5, 'n_estimators': 50, 'objective': 'binary:logistic', 'subsample': 0.1}

# %%
df_features.get_bool_features()

# %%
df = pd.read_csv("Datasets/testing.csv")
display(df.shape)
df.head()

# %%
df["broker_id"].value_counts()
