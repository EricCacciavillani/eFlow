# %% [markdown]
# Find the markdown blocks that say interaction required! The notebook should take care of the rest!

# %% [markdown]
# # Import libs

# %%
import sys
import os
sys.path.append('..')
from eflow.foundation import DataPipeline,DataFrameTypes
from eflow.model_analysis import ClassificationAnalysis
from eflow.utils.modeling_utils import optimize_model_grid
from eflow.utils.eflow_utils import get_type_holder_from_pipeline, remove_unconnected_pipeline_segments
from eflow.utils.pandas_utils import data_types_table
from eflow.utils.sys_utils import get_all_directories_from_path

import pandas as pd
import numpy as np
import scikitplot as skplt
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
import copy
import pickle
from IPython.display import clear_output

# %%
# # Additional add ons
# !pip install pandasgui
# !pip install pivottablejs
# clear_output()

# %%
# %matplotlib notebook
# %matplotlib inline

# %% [markdown]
# ## Declare Project Variables

# %% [markdown]
# ### Interaction required

# %%
dataset_path = "Datasets/train.csv"

# -----
dataset_name = "Home Insurance Cross Sell Prediction"
pipeline_name = "Home Insurance Pipeline"
# -----

# -----
notebook_mode = True

# %% [markdown]
# ## Clean out segment space

# %%
remove_unconnected_pipeline_segments()

# %% [markdown]
# # Import dataset

# %%
df = pd.read_csv(dataset_path)
shape_df = pd.DataFrame.from_dict({'Rows': [df.shape[0]],
                                   'Columns': [df.shape[1]]})
display(shape_df)
display(df.head(30))
# Out:
#      Rows  Columns
# 0  381109       12
#     id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0    1    Male   44                1         28.0                   0
# 1    2    Male   76                1          3.0                   0
# 2    3    Male   47                1         28.0                   0
# 3    4    Male   21                1         11.0                   1
# 4    5  Female   29                1         41.0                   1
# 5    6  Female   24                1         33.0                   0
# 6    7    Male   23                1         11.0                   0
# 7    8  Female   56                1         28.0                   0
# 8    9  Female   24                1          3.0                   1
# 9   10  Female   32                1          6.0                   1
# 10  11  Female   47                1         35.0                   0
# 11  12  Female   24                1         50.0                   1
# 12  13  Female   41                1         15.0                   1
# 13  14    Male   76                1         28.0                   0
# 14  15    Male   71                1         28.0                   1
# 15  16    Male   37                1          6.0                   0
# 16  17  Female   25                1         45.0                   0
# 17  18  Female   25                1         35.0                   1
# 18  19    Male   42                1         28.0                   0
# 19  20  Female   60                1         33.0                   0
# 20  21    Male   65                1         28.0                   0
# 21  22    Male   49                1         28.0                   0
# 22  23    Male   23                1         50.0                   1
# 23  24    Male   44                1         28.0                   0
# 24  25    Male   34                1         15.0                   1
# 25  26  Female   21                1         28.0                   1
# 26  27  Female   51                1         28.0                   0
# 27  28    Male   26                1          6.0                   1
# 28  29  Female   25                1          8.0                   1
# 29  30    Male   57                1         11.0                   0
#
#    Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0    > 2 Years            Yes         40454.0                  26.0      217
# 1     1-2 Year             No         33536.0                  26.0      183
# 2    > 2 Years            Yes         38294.0                  26.0       27
# 3     < 1 Year             No         28619.0                 152.0      203
# 4     < 1 Year             No         27496.0                 152.0       39
# 5     < 1 Year            Yes          2630.0                 160.0      176
# 6     < 1 Year            Yes         23367.0                 152.0      249
# 7     1-2 Year            Yes         32031.0                  26.0       72
# 8     < 1 Year             No         27619.0                 152.0       28
# 9     < 1 Year             No         28771.0                 152.0       80
# 10    1-2 Year            Yes         47576.0                 124.0       46
# 11    < 1 Year             No         48699.0                 152.0      289
# 12    1-2 Year             No         31409.0                  14.0      221
# 13    1-2 Year            Yes         36770.0                  13.0       15
# 14    1-2 Year             No         46818.0                  30.0       58
# 15    1-2 Year            Yes          2630.0                 156.0      147
# 16    < 1 Year            Yes         26218.0                 160.0      256
# 17    < 1 Year             No         46622.0                 152.0      299
# 18    1-2 Year            Yes         33667.0                 124.0      158
# 19    1-2 Year            Yes         32363.0                 124.0      102
# 20    1-2 Year            Yes         41184.0                 124.0      116
# 21    1-2 Year            Yes         50791.0                 124.0      177
# 22    < 1 Year             No         45283.0                 152.0      232
# 23    1-2 Year            Yes         41852.0                 163.0       60
# 24    1-2 Year             No         38111.0                 152.0      180
# 25    < 1 Year             No         61964.0                 152.0       72
# 26    1-2 Year            Yes         38341.0                 124.0       49
# 27    < 1 Year             No         19135.0                 152.0       57
# 28    < 1 Year             No         27946.0                 152.0      223
# 29    1-2 Year            Yes         25679.0                 157.0      232
#
#     Response
# 0          1
# 1          0
# 2          1
# 3          0
# 4          0
# 5          0
# 6          0
# 7          1
# 8          0
# 9          0
# 10         1
# 11         0
# 12         0
# 13         0
# 14         0
# 15         1
# 16         0
# 17         0
# 18         0
# 19         1
# 20         0
# 21         0
# 22         0
# 23         0
# 24         0
# 25         0
# 26         1
# 27         0
# 28         0
# 29         1

# %%
data_types_table(df)
# Out:
#                      Data Types
# Features
# Region_Code             float64
# Annual_Premium          float64
# Policy_Sales_Channel    float64
# id                        int64
# Age                       int64
# Driving_License           int64
# Previously_Insured        int64
# Vintage                   int64
# Response                  int64
# Gender                   object
# Vehicle_Age              object
# Vehicle_Damage           object

# %% [markdown]
# # Loading and init df_features

# %%
# Option: 1
# df_features = get_type_holder_from_pipeline(pipeline_name)

# %%
# Option: 2
df_features = DataFrameTypes()
df_features.init_on_json_file(os.getcwd() + f"/eflow Data/{dataset_name}/df_features.json")

# %%
df_features.display_features(display_dataframes=True,
                             notebook_mode=notebook_mode)
# Out:
#                    Data Types
# Features
# Gender                 string
# Vehicle_Age            string
# Previously_Insured       bool
# Vehicle_Damage           bool
# Response                 bool
# Vintage               integer
# Age                   integer
# Annual_Premium        integer

# %% [markdown]
# # Any extra processing before eflow DataPipeline

# %% [markdown]
# # Setup pipeline structure

# %% [markdown]
# ### Interaction Required

# %%
main_pipe = DataPipeline(pipeline_name,
                         df,
                         df_features)
# Out:
# The file 'root_pipeline.json' exist!
# Now configuring object with proper pipeline segments...
# Removing the feature: "id"
# Removing the feature: "Driving_License"
# Removing the feature: "Policy_Sales_Channel"
# Removing the feature: "Region_Code"

# %%
main_pipe.perform_pipeline(df,
                           df_features)

# %%
df
# Out:
#         Age  Previously_Insured  Vehicle_Damage  Annual_Premium  Vintage  \
# 0        44                   0               1         40454.0      217
# 1        76                   0               0         33536.0      183
# 2        47                   0               1         38294.0       27
# 3        21                   1               0         28619.0      203
# 4        29                   1               0         27496.0       39
# ...     ...                 ...             ...             ...      ...
# 381104   74                   1               0         30170.0       88
# 381105   30                   1               0         40016.0      131
# 381106   21                   1               0         35118.0      161
# 381107   68                   0               1         44617.0       74
# 381108   46                   0               0         41777.0      237
#
#         Response  Gender_F  Gender_M  Vehicle_Age_1-2 Year  \
# 0              1     False      True                 False
# 1              0     False      True                  True
# 2              1     False      True                 False
# 3              0     False      True                 False
# 4              0      True     False                 False
# ...          ...       ...       ...                   ...
# 381104         0     False      True                  True
# 381105         0     False      True                 False
# 381106         0     False      True                 False
# 381107         0      True     False                 False
# 381108         0     False      True                  True
#
#         Vehicle_Age_< 1 Year  Vehicle_Age_> 2 Years
# 0                      False                   True
# 1                      False                  False
# 2                      False                   True
# 3                       True                  False
# 4                       True                  False
# ...                      ...                    ...
# 381104                 False                  False
# 381105                  True                  False
# 381106                  True                  False
# 381107                 False                   True
# 381108                 False                  False
#
# [381109 rows x 11 columns]

# %%
df["Response"].value_counts()
# Out:
# 0    334399
# 1     46710
# Name: Response, dtype: int64

# %% [markdown]
# # Seperate out data into train and test sets

# %%
X = df.drop(columns=df_features.target_feature()).values
y = df[df_features.target_feature()].values

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=517, stratify=y,
)

# %%
feature_order = list(df.columns)

# %%
del df

# %%
del X
del y

# %% [markdown]
# # Fit Models and view results

# %%
from sklearn.metrics import make_scorer, fbeta_score

f2_score = make_scorer(fbeta_score, beta=2, pos_label=1)

# %%
# Find best parameters for model
param_grid = {
    "max_depth": list(range(1, 4)),
    "min_samples_leaf": list(range(80, 130, 5)),
    "criterion": ["gini", "entropy"],
}

model, best_params = optimize_model_grid(
    model=DecisionTreeClassifier(class_weight={0:2,1:8}),
    X_train=X_train,
    y_train=y_train,
    param_grid=param_grid,
    scoring="f1_macro",
    n_jobs=-1,
    verbose=2
)
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:   29.3s
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:   56.2s finished
# Tuned Parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 80}
# Best score on trained data was 0.617017

# %%
from sklearn.metrics import SCORERS
sorted(SCORERS.keys())
# Out:
# ['accuracy',
#  'adjusted_mutual_info_score',
#  'adjusted_rand_score',
#  'average_precision',
#  'balanced_accuracy',
#  'completeness_score',
#  'explained_variance',
#  'f1',
#  'f1_macro',
#  'f1_micro',
#  'f1_samples',
#  'f1_weighted',
#  'fowlkes_mallows_score',
#  'homogeneity_score',
#  'jaccard',
#  'jaccard_macro',
#  'jaccard_micro',
#  'jaccard_samples',
#  'jaccard_weighted',
#  'max_error',
#  'mutual_info_score',
#  'neg_brier_score',
#  'neg_log_loss',
#  'neg_mean_absolute_error',
#  'neg_mean_gamma_deviance',
#  'neg_mean_poisson_deviance',
#  'neg_mean_squared_error',
#  'neg_mean_squared_log_error',
#  'neg_median_absolute_error',
#  'neg_root_mean_squared_error',
#  'normalized_mutual_info_score',
#  'precision',
#  'precision_macro',
#  'precision_micro',
#  'precision_samples',
#  'precision_weighted',
#  'r2',
#  'recall',
#  'recall_macro',
#  'recall_micro',
#  'recall_samples',
#  'recall_weighted',
#  'roc_auc',
#  'roc_auc_ovo',
#  'roc_auc_ovo_weighted',
#  'roc_auc_ovr',
#  'roc_auc_ovr_weighted',
#  'v_measure_score']

# %%
model_name = repr(model).split("(")[0]

# %%
model_analysis = ClassificationAnalysis(dataset_name=dataset_name,
                                        model=model,
                                        model_name=model_name,
                                        feature_order=feature_order,
                                        target_feature=df_features.target_feature(),
                                        pred_funcs_dict={"Probabilities function":model.predict_proba,
                                                         "Predict function":model.predict},
                                        sample_data=X_train[0],
                                        notebook_mode=notebook_mode,
                                        df_features=df_features)

# %%
model_analysis.perform_analysis(X=X_train,
                                y=y_train,
                                dataset_name="Train Data",
                                classification_error_analysis=False,
                                classification_correct_analysis=False)
# Out:
# ------------------------------Train Data------------------------------
# Now running classification on Probabilities function on no thresholds.
#
# Shape of the data is (266776, 10)
#                     Metric Scores
# Precision(micro)           0.7094
# Precision(macro)           0.6294
# Precision(weighted)        0.8919
# MCC                        0.3841
# Recall(micro)              0.7094
# Recall(macro)              0.7850
# Recall(weighted)           0.7094
# F1-Score(micro)            0.7094
# F1-Score(macro)            0.6164
# F1-Score(weighted)         0.7590
# Accuracy                   0.7094
# /Users/ericcacciavillani/anaconda3/envs/Home_Insurance/lib/python3.7/site-packages/scikitplot/metrics.py:443: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
#   mean_tpr += interp(all_fpr, fpr_dict[i], tpr_dict[i])
# ----------------------------------------------------------------------
#
#
#
#
#
# Now running classification on Predict function
#
# Shape of the data is (266776, 10)
#                     Metric Scores
# Precision(micro)           0.7094
# Precision(macro)           0.6294
# Precision(weighted)        0.8919
# MCC                        0.3841
# Recall(micro)              0.7094
# Recall(macro)              0.7850
# Recall(weighted)           0.7094
# F1-Score(micro)            0.7094
# F1-Score(macro)            0.6164
# F1-Score(weighted)         0.7590
# Accuracy                   0.7094
# ----------------------------------------------------------------------

# %%
# for pred_name in model_analysis.get_predictions_names():
#     print(f"Prediction name: {pred_name}")

#     for threshold_dir in get_all_directories_from_path(model_analysis.folder_path + f"Train Data/{pred_name}/"):
#         prediction_path = model_analysis.folder_path + f"Train Data/{pred_name}/"
#         if "Thresholds" in threshold_dir:
#             prediction_path += f"{threshold_dir}/"
            
#         for answered_dir in get_all_directories_from_path(prediction_path):
#             for sub_dir in get_all_directories_from_path(prediction_path + f"{answered_dir}/"):
#                 print(prediction_path + f"{answered_dir}/{sub_dir}/")
#                 infile = open(prediction_path + f"{answered_dir}/{sub_dir}/Train Data/_Extras/Statistics/Stat methods of features dataframes.pkl",'rb')
#                 stat_methods_dict = pickle.load(infile)
#                 infile.close()

#                 for stats_method in stat_methods_dict.keys():
#                     print(stats_method)
#                     display(stat_methods_dict[stats_method].round(6))
#                     all_feature_relationship = set()
#                     for feature_relationship in stat_methods_dict[stats_method][:10].index.to_list():
#                         for feature in feature_relationship.split(" compared to "):
#                             all_feature_relationship.add(feature)
#                     print(all_feature_relationship)
#                     print("-----" * 12 + "\n\n")

#                 del stat_methods_dict
# Out:
# /Users/ericcacciavillani/anaconda3/envs/Home_Insurance/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
model_analysis.perform_analysis(X=X_test,
                                y=y_test,
                                dataset_name="Test Data",
                                classification_error_analysis=False,
                                classification_correct_analysis=False)
# Out:
# ------------------------------Test Data------------------------------
# Now running classification on Probabilities function on no thresholds.
#
# Shape of the data is (114333, 10)
#                     Metric Scores
# Precision(micro)           0.7109
# Precision(macro)           0.6310
# Precision(weighted)        0.8932
# MCC                        0.3889
# Recall(micro)              0.7109
# Recall(macro)              0.7885
# Recall(weighted)           0.7109
# F1-Score(micro)            0.7109
# F1-Score(macro)            0.6184
# F1-Score(weighted)         0.7602
# Accuracy                   0.7109
# /Users/ericcacciavillani/anaconda3/envs/Home_Insurance/lib/python3.7/site-packages/scikitplot/metrics.py:443: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
#   mean_tpr += interp(all_fpr, fpr_dict[i], tpr_dict[i])
# ---------------------------------------------------------------------
#
#
#
#
#
# Now running classification on Predict function
#
# Shape of the data is (114333, 10)
#                     Metric Scores
# Precision(micro)           0.7109
# Precision(macro)           0.6310
# Precision(weighted)        0.8932
# MCC                        0.3889
# Recall(micro)              0.7109
# Recall(macro)              0.7885
# Recall(weighted)           0.7109
# F1-Score(micro)            0.7109
# F1-Score(macro)            0.6184
# F1-Score(weighted)         0.7602
# Accuracy                   0.7109
# ---------------------------------------------------------------------

# %%
# for pred_name in model_analysis.get_predictions_names():
#     print(f"Prediction name: {pred_name}")

#     for threshold_dir in get_all_directories_from_path(model_analysis.folder_path + f"Test Data/{pred_name}/"):
#         prediction_path = model_analysis.folder_path + f"Test Data/{pred_name}/"
#         if "Thresholds" in threshold_dir:
#             prediction_path += f"{threshold_dir}/"
            
#         for answered_dir in get_all_directories_from_path(prediction_path):
#             for sub_dir in get_all_directories_from_path(prediction_path + f"{answered_dir}/"):
#                 print(prediction_path + f"{answered_dir}/{sub_dir}/")
#                 infile = open(prediction_path + f"{answered_dir}/{sub_dir}/Test Data/_Extras/Statistics/Stat methods of features dataframes.pkl",'rb')
#                 stat_methods_dict = pickle.load(infile)
#                 infile.close()

#                 for stats_method in stat_methods_dict.keys():
#                     print(stats_method)
#                     display(stat_methods_dict[stats_method].round(6))
#                     all_feature_relationship = set()
#                     for feature_relationship in stat_methods_dict[stats_method][:10].index.to_list():
#                         for feature in feature_relationship.split(" compared to "):
#                             all_feature_relationship.add(feature)
#                     print(all_feature_relationship)
#                     print("-----" * 12 + "\n\n")

#                 del stat_methods_dict
# Out:
# /Users/ericcacciavillani/anaconda3/envs/Home_Insurance/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
