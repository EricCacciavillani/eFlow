# %% [markdown]
# Find the markdown blocks that say interaction required! The notebook should take care of the rest!

# %% [markdown]
# # Import libs

# %%
import sys
import os
sys.path.append('..')
from eflow.foundation import DataPipeline,DataFrameTypes
from eflow.model_analysis import ClassificationAnalysis
from eflow.utils.modeling_utils import optimize_model_grid
from eflow.utils.eflow_utils import get_type_holder_from_pipeline, remove_unconnected_pipeline_segments
from eflow.utils.pandas_utils import data_types_table
from eflow.auto_modeler import AutoCluster
from eflow.data_pipeline_segments import DataEncoder

import pandas as pd
import numpy as np
import scikitplot as skplt
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
import copy
import pickle
from IPython.display import clear_output

# %%
# # Additional add ons
# !pip install pandasgui
# !pip install pivottablejs
# clear_output()

# %%
# %matplotlib notebook
# %matplotlib inline

# %% [markdown]
# ## Declare Project Variables

# %% [markdown]
# ### Interaction required

# %%
dataset_path = "Datasets/titanic_train.csv"

# -----
dataset_name = "Titanic Data"
pipeline_name = "Titanic Pipeline"

# -----


# -----
notebook_mode = True

# %% [markdown]
# ## Clean out segment space

# %%
remove_unconnected_pipeline_segments()

# %% [markdown]
# # Import dataset

# %%
df = pd.read_csv(dataset_path)
shape_df = pd.DataFrame.from_dict({'Rows': [df.shape[0]],
                                   'Columns': [df.shape[1]]})
display(shape_df)
display(df.head(30))
# Out:
#    Rows  Columns
# 0   891       12
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# 26           27         0       3
# 27           28         0       1
# 28           29         1       3
# 29           30         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                               Rice, Master. Eugene    male   2.0      4
# 17                       Williams, Mr. Charles Eugene    male   NaN      0
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                            Masselmani, Mrs. Fatima  female   NaN      0
# 20                               Fynney, Mr. Joseph J    male  35.0      0
# 21                              Beesley, Mr. Lawrence    male  34.0      0
# 22                        McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
# 24                      Palsson, Miss. Torborg Danira  female   8.0      3
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 26                            Emir, Mr. Farred Chehab    male   NaN      0
# 27                     Fortune, Mr. Charles Alexander    male  19.0      3
# 28                      O'Dwyer, Miss. Ellen "Nellie"  female   NaN      0
# 29                                Todoroff, Mr. Lalio    male   NaN      0
#
#     Parch            Ticket      Fare        Cabin Embarked
# 0       0         A/5 21171    7.2500          NaN        S
# 1       0          PC 17599   71.2833          C85        C
# 2       0  STON/O2. 3101282    7.9250          NaN        S
# 3       0            113803   53.1000         C123        S
# 4       0            373450    8.0500          NaN        S
# 5       0            330877    8.4583          NaN        Q
# 6       0             17463   51.8625          E46        S
# 7       1            349909   21.0750          NaN        S
# 8       2            347742   11.1333          NaN        S
# 9       0            237736   30.0708          NaN        C
# 10      1           PP 9549   16.7000           G6        S
# 11      0            113783   26.5500         C103        S
# 12      0         A/5. 2151    8.0500          NaN        S
# 13      5            347082   31.2750          NaN        S
# 14      0            350406    7.8542          NaN        S
# 15      0            248706   16.0000          NaN        S
# 16      1            382652   29.1250          NaN        Q
# 17      0            244373   13.0000          NaN        S
# 18      0            345763   18.0000          NaN        S
# 19      0              2649    7.2250          NaN        C
# 20      0            239865   26.0000          NaN        S
# 21      0            248698   13.0000          D56        S
# 22      0            330923    8.0292          NaN        Q
# 23      0            113788   35.5000           A6        S
# 24      1            349909   21.0750          NaN        S
# 25      5            347077   31.3875          NaN        S
# 26      0              2631    7.2250          NaN        C
# 27      2             19950  263.0000  C23 C25 C27        S
# 28      0            330959    7.8792          NaN        Q
# 29      0            349216    7.8958          NaN        S

# %%
data_types_table(df)
# Out:
#             Data Types
# Features
# Age            float64
# Fare           float64
# PassengerId      int64
# Survived         int64
# Pclass           int64
# SibSp            int64
# Parch            int64
# Name            object
# Sex             object
# Ticket          object
# Cabin           object
# Embarked        object

# %% [markdown]
# # Loading and init df_features

# %%
# Option: 1
# df_features = get_type_holder_from_pipeline(pipeline_name)

# %%
# Option: 2
df_features = DataFrameTypes()
df_features.init_on_json_file(os.getcwd() + f"/eflow Data/{dataset_name}/df_features.json")

# %%
df_features.display_features(display_dataframes=True,
                             notebook_mode=notebook_mode)
# Out:
#          Data Types
# Features
# Cabin        string
# Sex          string
# Embarked     string
# Pclass       string
# Survived       bool
# SibSp       integer
# Parch       integer
# Fare          float
# Age           float

# %%
qualtative_features = df_features.string_features() | df_features.categorical_features()
qualtative_features
# Out:
# {'Cabin', 'Embarked', 'Pclass', 'Sex'}

# %% [markdown]
# # Any extra processing before eflow DataPipeline

# %% [markdown]
# # Setup pipeline structure

# %% [markdown]
# ### Interaction Required

# %%
main_pipe = DataPipeline(pipeline_name,
                         df,
                         df_features)
# Out:
# The file 'root_pipeline.json' exist!
# Now configuring object with proper pipeline segments...
# Removing the feature: "PassengerId"
# Removing the feature: "Ticket"
# Removing the feature: "Name"

# %%
main_pipe.perform_pipeline(df,
                           df_features)

# %%
df
# Out:
#      Survived        Age  SibSp  Parch     Fare  Pclass_1  Pclass_2  Pclass_3  \
# 0           0  22.000000      1      0   7.2500     False     False      True
# 1           1  38.000000      1      0  71.2833      True     False     False
# 2           1  26.000000      0      0   7.9250     False     False      True
# 3           1  35.000000      1      0  53.1000      True     False     False
# 4           0  35.000000      0      0   8.0500     False     False      True
# ..        ...        ...    ...    ...      ...       ...       ...       ...
# 886         0  27.000000      0      0  13.0000     False      True     False
# 887         1  19.000000      0      0  30.0000      True     False     False
# 888         0  28.312774      1      2  23.4500     False     False      True
# 889         1  26.000000      0      0  30.0000      True     False     False
# 890         0  32.000000      0      0   7.7500     False     False      True
#
#      Embarked_Cherbourg  Embarked_Queenstown  Embarked_Southampton  \
# 0                 False                False                  True
# 1                  True                False                 False
# 2                 False                False                  True
# 3                 False                False                  True
# 4                 False                False                  True
# ..                  ...                  ...                   ...
# 886               False                False                  True
# 887               False                False                  True
# 888               False                False                  True
# 889                True                False                 False
# 890               False                 True                 False
#
#      Sex_female  Sex_male
# 0         False      True
# 1          True     False
# 2          True     False
# 3          True     False
# 4         False      True
# ..          ...       ...
# 886       False      True
# 887        True     False
# 888        True     False
# 889       False      True
# 890       False      True
#
# [891 rows x 13 columns]

# %% [markdown]
# # Generate clustering models with automodeler

# %%
auto_cluster = AutoCluster(df,
                           project_sub_dir=dataset_name,
                           overwrite_full_path=None,
                           notebook_mode=True,
                           pca_perc=.8)
# Out:
# Inspecting scaled results!
#                               Mean  Standard Dev
# Survived              3.987333e-17           1.0
# Age                  -4.944293e-16           1.0
# SibSp                 4.386066e-17           1.0
# Parch                 5.382900e-17           1.0
# Fare                  3.987333e-18           1.0
# Pclass_1             -7.575933e-17           1.0
# Pclass_2              1.993666e-17           1.0
# Pclass_3             -6.778466e-17           1.0
# Embarked_Cherbourg   -1.993666e-17           1.0
# Embarked_Queenstown   0.000000e+00           1.0
# Embarked_Southampton -8.373399e-17           1.0
# Sex_female            3.987333e-17           1.0
# Sex_male             -1.156327e-16           1.0
# Inspecting applied scaler and pca results!
#                         Mean  Standard Dev
# PCA_Feature_1  -1.594933e-17  1.755623e+00
# PCA_Feature_2  -7.177199e-17  1.473689e+00
# PCA_Feature_3  -3.189866e-17  1.404598e+00
# PCA_Feature_4  -3.588600e-17  1.236644e+00
# PCA_Feature_5  -2.791133e-17  1.062925e+00
# PCA_Feature_6  -5.980999e-18  9.733969e-01
# PCA_Feature_7   4.386066e-17  8.676079e-01
# PCA_Feature_8   1.594933e-17  7.507034e-01
# PCA_Feature_9   6.180366e-17  6.864172e-01
# PCA_Feature_10 -6.977833e-17  6.156816e-01
# PCA_Feature_11  2.864554e-18  4.086427e-16
# PCA_Feature_12 -1.602688e-17  3.572792e-16
# PCA_Feature_13 -2.232697e-17  1.965284e-16
# After applying pca with a cutoff percentage 0.8% for the cumulative index. Using features 1 to 6
# Old shape (891, 13)
# New shape (891, 6)
#
# Inspecting data after final scaler applied!
#                        Mean  Standard Dev
# PCA_Feature_1 -3.987333e-18           1.0
# PCA_Feature_2 -1.594933e-17           1.0
# PCA_Feature_3 -4.984166e-18           1.0
# PCA_Feature_4 -1.395567e-17           1.0
# PCA_Feature_5 -3.987333e-18           1.0
# PCA_Feature_6  5.980999e-18           1.0
# Found past models in directory structure! Attempting to re-initalize models...
# K-Means_Clusters=4 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/K-Means/Clusters=4/K-Means_Clusters=4.pkl
#
# K-Means_Clusters=5 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/K-Means/Clusters=5/K-Means_Clusters=5.pkl
#
# K-Means_Clusters=6 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/K-Means/Clusters=6/K-Means_Clusters=6.pkl
#
# K-Means_Clusters=8 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/K-Means/Clusters=8/K-Means_Clusters=8.pkl
#
# K-Means_Clusters=7 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/K-Means/Clusters=7/K-Means_Clusters=7.pkl
#
# K-Means_Clusters=9 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/K-Means/Clusters=9/K-Means_Clusters=9.pkl
#
# Somsc_Clusters=5 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/Somsc/Clusters=5/Somsc_Clusters=5.pkl
#
# Somsc_Clusters=6 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/Somsc/Clusters=6/Somsc_Clusters=6.pkl
#
# Somsc_Clusters=7 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/Somsc/Clusters=7/Somsc_Clusters=7.pkl
#
# Cure_Clusters=4 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/Cure/Clusters=4/Cure_Clusters=4.pkl
#
# Cure_Clusters=11 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/Cure/Clusters=11/Cure_Clusters=11.pkl
#
# Cure_Clusters=9 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/Cure/Clusters=9/Cure_Clusters=9.pkl
#
# Cure_Clusters=3 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/Cure/Clusters=3/Cure_Clusters=3.pkl
#
# Cure_Clusters=2 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/Cure/Clusters=2/Cure_Clusters=2.pkl
#
# Cure_Clusters=10 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/Cure/Clusters=10/Cure_Clusters=10.pkl
#
# K-Medoids_Clusters=4 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/K-Medoids/Clusters=4/K-Medoids_Clusters=4.pkl
#
# K-Medoids_Clusters=10 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/K-Medoids/Clusters=10/K-Medoids_Clusters=10.pkl
#
# K-Medoids_Clusters=5 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/K-Medoids/Clusters=5/K-Medoids_Clusters=5.pkl
#
# K-Medoids_Clusters=6 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/K-Medoids/Clusters=6/K-Medoids_Clusters=6.pkl
#
# K-Medoids_Clusters=3 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/K-Medoids/Clusters=3/K-Medoids_Clusters=3.pkl
#
# K-Medoids_Clusters=8 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/K-Medoids/Clusters=8/K-Medoids_Clusters=8.pkl
#
# K-Medoids_Clusters=7 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/K-Medoids/Clusters=7/K-Medoids_Clusters=7.pkl
#
# K-Medoids_Clusters=9 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/K-Medoids/Clusters=9/K-Medoids_Clusters=9.pkl
#
# Fuzzy C-Means_Clusters=4 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/Fuzzy C-Means/Clusters=4/Fuzzy C-Means_Clusters=4.pkl
#
# Fuzzy C-Means_Clusters=5 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/Fuzzy C-Means/Clusters=5/Fuzzy C-Means_Clusters=5.pkl
#
# Fuzzy C-Means_Clusters=6 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/Fuzzy C-Means/Clusters=6/Fuzzy C-Means_Clusters=6.pkl
#
# Fuzzy C-Means_Clusters=3 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/Fuzzy C-Means/Clusters=3/Fuzzy C-Means_Clusters=3.pkl
#
# Fuzzy C-Means_Clusters=2 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/Fuzzy C-Means/Clusters=2/Fuzzy C-Means_Clusters=2.pkl
#
# Fuzzy C-Means_Clusters=8 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/Fuzzy C-Means/Clusters=8/Fuzzy C-Means_Clusters=8.pkl
#
# Fuzzy C-Means_Clusters=1 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/Fuzzy C-Means/Clusters=1/Fuzzy C-Means_Clusters=1.pkl
#
# Fuzzy C-Means_Clusters=7 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/Fuzzy C-Means/Clusters=7/Fuzzy C-Means_Clusters=7.pkl
#
# K-Medians_Clusters=4 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/K-Medians/Clusters=4/K-Medians_Clusters=4.pkl
#
# K-Medians_Clusters=10 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/K-Medians/Clusters=10/K-Medians_Clusters=10.pkl
#
# K-Medians_Clusters=11 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/K-Medians/Clusters=11/K-Medians_Clusters=11.pkl
#
# K-Medians_Clusters=5 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/K-Medians/Clusters=5/K-Medians_Clusters=5.pkl
#
# K-Medians_Clusters=6 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/K-Medians/Clusters=6/K-Medians_Clusters=6.pkl
#
# K-Medians_Clusters=3 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/K-Medians/Clusters=3/K-Medians_Clusters=3.pkl
#
# K-Medians_Clusters=2 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/K-Medians/Clusters=2/K-Medians_Clusters=2.pkl
#
# K-Medians_Clusters=8 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/K-Medians/Clusters=8/K-Medians_Clusters=8.pkl
#
# K-Medians_Clusters=7 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/K-Medians/Clusters=7/K-Medians_Clusters=7.pkl
#
# K-Medians_Clusters=9 was found at /Users/ericcacciavillani/Desktop/Coding/Python_Files/Artificial_Intelligence/Data Mining/eFlow/testing/eflow Data/Titanic Data/Auto Clustering/Models/K-Medians/Clusters=9/K-Medians_Clusters=9.pkl

# %% [markdown]
# ### Temporialy remove dataframe to save RAM for processing

# %%
del df

# %% [markdown]
# # Inspect Hierarchical models

# %%
# auto_cluster.visualize_hierarchical_clustering()

# %%
auto_cluster.create_elbow_models(
                                 sequences=10,
                                 max_k_value=11,
                                 display_visuals=True)
# Out:
# K-Means Elbow Seq Count 1: 100%|██████████| 11/11 [00:00<00:00, 15.45it/s, model_count=11]
# K-Means Elbow Seq Count 2: 100%|██████████| 11/11 [00:00<00:00, 18.79it/s, model_count=11]
# K-Means Elbow Seq Count 3: 100%|██████████| 11/11 [00:00<00:00, 16.66it/s, model_count=11]
# K-Means Elbow Seq Count 4: 100%|██████████| 11/11 [00:00<00:00, 18.75it/s, model_count=11]
# K-Means Elbow Seq Count 5: 100%|██████████| 11/11 [00:00<00:00, 16.49it/s, model_count=11]
# K-Means Elbow Seq Count 6: 100%|██████████| 11/11 [00:00<00:00, 17.97it/s, model_count=11]
# K-Means Elbow Seq Count 7: 100%|██████████| 11/11 [00:00<00:00, 16.63it/s, model_count=11]
# K-Means Elbow Seq Count 8: 100%|██████████| 11/11 [00:00<00:00, 18.54it/s, model_count=11]
# K-Means Elbow Seq Count 9: 100%|██████████| 11/11 [00:00<00:00, 16.39it/s, model_count=11]
# K-Means Elbow Seq Count 10: 100%|██████████| 11/11 [00:00<00:00, 18.39it/s, model_count=11]
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# convex
# elbow_cluster:7
# convex
# elbow_cluster:7
# convex
# elbow_cluster:7
# convex
# elbow_cluster:5
# convex
# elbow_cluster:6
# convex
# elbow_cluster:6
# convex
# elbow_cluster:7
# convex
# elbow_cluster:7
# convex
# elbow_cluster:7
# convex
# elbow_cluster:7
# [5345.999999999996, 4501.091589836302, 3923.747391467457, 3098.9516242272293, 3051.5399526856036, 2337.4870039809516, 1875.0742971931882, 1683.2710432980282, 1593.8783304983792, 1333.86080327808, 1237.664910911769]
#   Proximity Knees  Counts
# 0               6      10
# 1               7       9
# 2               8       7
# 4               5       3
# 3               4       1
#   Main Knees  Counts
# 0          7       7
# 2          6       2
# 1          5       1
# Somsc Elbow Seq Count 1: 100%|██████████| 11/11 [00:00<00:00, 18.64it/s, model_count=11]
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# convex
# elbow_cluster:6
# [5345.999999999996, 4563.181329613961, 3861.254277611249, 2879.4968249039216, 2394.1768828967092, 1918.7671435874695, 1663.0697560096817, 1466.634694966624, 1274.3341892725111, 1182.4562764068662, 1050.3844206890615]
#   Proximity Knees  Counts
# 0               5       1
# 1               6       1
# 2               7       1
#   Main Knees  Counts
# 0          6       1
# Cure Elbow Seq Count 1: 100%|██████████| 11/11 [00:01<00:00, 10.02it/s, model_count=11]
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# convex
# elbow_cluster:3
# [5345.999999999996, 4501.091589836301, 4155.5767308676395, 3978.984955755752, 3931.4652223446183, 3920.4942373284757, 3730.357059730127, 3715.0919218096747, 3705.809207545254, 3657.4383838151193, 2882.6649067349017]
#   Proximity Knees  Counts
# 0               2       1
# 1               3       1
# 2               4       1
#   Main Knees  Counts
# 0          3       1
# K-Medoids Elbow Seq Count 1: 100%|██████████| 11/11 [00:00<00:00, 16.58it/s, model_count=11]
# K-Medoids Elbow Seq Count 2: 100%|██████████| 11/11 [00:00<00:00, 15.55it/s, model_count=11]
# K-Medoids Elbow Seq Count 3: 100%|██████████| 11/11 [00:00<00:00, 17.80it/s, model_count=11]
# K-Medoids Elbow Seq Count 4: 100%|██████████| 11/11 [00:00<00:00, 15.12it/s, model_count=11]
# K-Medoids Elbow Seq Count 5: 100%|██████████| 11/11 [00:00<00:00, 17.40it/s, model_count=11]
# K-Medoids Elbow Seq Count 6: 100%|██████████| 11/11 [00:00<00:00, 15.59it/s, model_count=11]
# K-Medoids Elbow Seq Count 7: 100%|██████████| 11/11 [00:00<00:00, 17.40it/s, model_count=11]
# K-Medoids Elbow Seq Count 8: 100%|██████████| 11/11 [00:00<00:00, 15.91it/s, model_count=11]
# K-Medoids Elbow Seq Count 9: 100%|██████████| 11/11 [00:00<00:00, 18.54it/s, model_count=11]
# K-Medoids Elbow Seq Count 10: 100%|██████████| 11/11 [00:00<00:00, 15.94it/s, model_count=11]
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# convex
# elbow_cluster:8
# convex
# elbow_cluster:4
# convex
# elbow_cluster:4
# convex
# elbow_cluster:6
# convex
# elbow_cluster:6
# convex
# elbow_cluster:4
# convex
# elbow_cluster:7
# convex
# elbow_cluster:5
# convex
# elbow_cluster:8
# convex
# elbow_cluster:9
# [5345.999999999996, 4501.091589836302, 3788.5845584991102, 3044.8895934401176, 2836.1090107022796, 2211.924875407707, 1876.8151147799924, 1709.482619957442, 1299.3828783728566, 1201.9209048690864, 1125.4431973641144]
# Something went wrong when trying to save the model: K-Medoids
# Something went wrong when trying to save the model: K-Medoids
# Something went wrong when trying to save the model: K-Medoids
#   Proximity Knees  Counts
# 5               5       6
# 0               7       5
# 1               8       4
# 4               4       4
# 6               6       4
# 2               9       3
# 3               3       3
# 7              10       1
#   Main Knees  Counts
# 1          4       3
# 0          8       2
# 2          6       2
# 3          7       1
# 4          5       1
# 5          9       1
# Fuzzy C-Means Elbow Seq Count 1: 100%|██████████| 11/11 [00:00<00:00, 12.85it/s, model_count=11]
# Fuzzy C-Means Elbow Seq Count 2: 100%|██████████| 11/11 [00:00<00:00, 12.86it/s, model_count=11]
# Fuzzy C-Means Elbow Seq Count 3: 100%|██████████| 11/11 [00:00<00:00, 12.27it/s, model_count=11]
# Fuzzy C-Means Elbow Seq Count 4: 100%|██████████| 11/11 [00:00<00:00, 12.79it/s, model_count=11]
# Fuzzy C-Means Elbow Seq Count 5: 100%|██████████| 11/11 [00:00<00:00, 13.52it/s, model_count=11]
# Fuzzy C-Means Elbow Seq Count 6: 100%|██████████| 11/11 [00:00<00:00, 12.41it/s, model_count=11]
# Fuzzy C-Means Elbow Seq Count 7: 100%|██████████| 11/11 [00:00<00:00, 12.35it/s, model_count=11]
# Fuzzy C-Means Elbow Seq Count 8: 100%|██████████| 11/11 [00:00<00:00, 12.44it/s, model_count=11]
# Fuzzy C-Means Elbow Seq Count 9: 100%|██████████| 11/11 [00:00<00:00, 12.42it/s, model_count=11]
# Fuzzy C-Means Elbow Seq Count 10: 100%|██████████| 11/11 [00:00<00:00, 13.34it/s, model_count=11]
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# concave
# elbow_cluster:2
# concave
# elbow_cluster:2
# concave
# elbow_cluster:2
# concave
# elbow_cluster:2
# concave
# elbow_cluster:2
# concave
# elbow_cluster:2
# concave
# elbow_cluster:2
# concave
# elbow_cluster:2
# concave
# elbow_cluster:2
# concave
# elbow_cluster:2
# [5345.999999999996, 4910.047265855051, 4780.844136675267, 4745.434882932209, 4129.911819690948, 2371.081276090588, 1985.9894627564358, 1683.6842207926982, 1401.4090593157669, 1237.7644835798549, 1129.9284793236557]
#   Proximity Knees  Counts
# 0               1      10
# 1               2      10
# 2               3      10
#   Main Knees  Counts
# 0          2      10
# K-Medians Elbow Seq Count 1: 100%|██████████| 11/11 [00:00<00:00, 11.27it/s, model_count=11]
# K-Medians Elbow Seq Count 2: 100%|██████████| 11/11 [00:00<00:00, 11.72it/s, model_count=11]
# K-Medians Elbow Seq Count 3: 100%|██████████| 11/11 [00:01<00:00, 10.90it/s, model_count=11]
# K-Medians Elbow Seq Count 4: 100%|██████████| 11/11 [00:00<00:00, 12.18it/s, model_count=11]
# K-Medians Elbow Seq Count 5: 100%|██████████| 11/11 [00:01<00:00, 10.81it/s, model_count=11]
# K-Medians Elbow Seq Count 6: 100%|██████████| 11/11 [00:00<00:00, 12.16it/s, model_count=11]
# K-Medians Elbow Seq Count 7: 100%|██████████| 11/11 [00:01<00:00, 10.99it/s, model_count=11]
# K-Medians Elbow Seq Count 8: 100%|██████████| 11/11 [00:00<00:00, 12.02it/s, model_count=11]
# K-Medians Elbow Seq Count 9: 100%|██████████| 11/11 [00:00<00:00, 11.48it/s, model_count=11]
# K-Medians Elbow Seq Count 10: 100%|██████████| 11/11 [00:00<00:00, 11.32it/s, model_count=11]
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# ../eflow/auto_modeler/cluster_master.py:1147: RankWarning: Polyfit may be poorly conditioned
#   curve = self.__determine_curve(inertias[i])
# convex
# elbow_cluster:7
# convex
# elbow_cluster:5
# convex
# elbow_cluster:4
# convex
# elbow_cluster:4
# convex
# elbow_cluster:7
# convex
# elbow_cluster:4
# convex
# elbow_cluster:4
# convex
# elbow_cluster:4
# convex
# elbow_cluster:4
# convex
# elbow_cluster:7
# [5345.999999999996, 4673.696624227614, 3842.0634089113364, 3686.4990403957063, 2772.5146283490085, 2808.098479255926, 2014.5453123462937, 2003.767425273727, 1939.0594338434253, 1189.3868282888945, 1224.9253303064186]
#   Proximity Knees  Counts
# 3               4       7
# 4               5       7
# 5               3       6
# 0               6       4
# 1               7       3
# 2               8       3
#   Main Knees  Counts
# 2          4       6
# 0          7       3
# 1          5       1
# [4, 5, 6]

# %%
1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-19-9e1622b385b6> in <module>
# ----> 1 1/0
#
# ZeroDivisionError: division by zero

# %%
import numpy as np
# data = [5345.999999999996, 4910.043444707498, 4786.6048724215425, 4746.052353365308, 4129.726105238373, 2371.081276090588, 1985.9894627564358, 1683.6842207926986, 1401.4090593157666, 1237.7644835798546, 1129.9284793236557]

__determine_curve(a)

# %%
df = pd.read_csv(dataset_path)
df

# %%
df_features.init_on_json_file(os.getcwd() + f"/eflow Data/{dataset_name}/df_features.json")
df_features.display_features(display_dataframes=True,
                             notebook_mode=notebook_mode)

# %%
main_pipe.perform_pipeline(df,
                           df_features)

# %%
df

# %%
data_encoder = DataEncoder(create_file=False)

# %%
data_encoder.revert_dummies(df,
                            df_features,
                            qualtative_features=list(df_features.get_dummy_encoded_features().keys()))

# %%
cluster_profile_dict = dict()
for feature_name in df.columns:
    if feature_name in  df_features.continuous_numerical_features():
        cluster_profile_dict[feature_name] = df[feature_name].mean()
    else:
        cluster_profile_dict[feature_name] = df[feature_name].mode()[0]
        if feature_name in df_features.bool_features():
            if  cluster_profile_dict[feature_name] == 1:
                cluster_profile_dict[feature_name] = True
            elif cluster_profile_dict[feature_name] == 0:
                cluster_profile_dict[feature_name] = False
cluster_profile_dict

# %%
# [i for i in range(0,len(cluster_profile_dict.keys()))]
# pd.DataFrame().from_dict([i for i in range(0,len(cluster_profile_dict.keys()))],cluster_profile_dict)

# pd.DataFrame([0]).from_dict(cluster_profile_dict, orient='columns')

# %%
# auto_cluster.evaluate_all_models(df,
#                                  df_features)

# %%
tolerance_levels = [round(2-(i/10),1) for i in range(0,50)]
tolerance_levels

# %%
from kneed import KneeLocator
# a = [5345.999999999996, 4769.071391049416, 4158.399592836868, 3340.8021023743877, 2870.109287596405, 2808.098479255926, 2014.5453123462937, 2003.767425273727, 1939.0594338434253, 1189.3868282888945, 1224.9253303064186]
a = [5345.999999999996, 4910.047265855051, 4780.844136675267, 4745.434882932209, 4129.911819690948, 2371.081276090588, 1985.9894627564358, 1683.6842207926982, 1401.4090593157669, 1237.7644835798549, 1129.9284793236557] 
# a = [5345.999999999996, 4521.432217603588, 3872.3758580658987, 3077.592076226511, 2971.3362953765613, 2253.7686132419553, 2084.59728529815, 1850.8071178779078, 1624.0985754171677, 1591.9988368277868, 1590.8698733117187]
for s in tolerance_levels:
    print(s)
    elbow_cluster = KneeLocator(range(1,12),
                                a,
                                curve='convex',
                                S=s,
                                online=True,
                                direction='decreasing').elbow
    display(elbow_cluster)
    print()

# %%
[i/10 for i in range(1,20)]

# %%
raise ValueError("Testing")

# %%
df.loc[[1,2,34]].reset_index(drop=True)

# %%
def __determine_curve(intertia):
    convex_count = 0
    concave_count = 0
    for i in range(2, len(intertia) + 1):
        x = range(len(intertia))
        print(intertia[0:i][-1])
        poly = np.polyfit(x[0:i],
                          intertia[0:i],
                          2)
        if poly[1] > 0:
            print("Conv")
            convex_count += 1
        else:
            print("Cave")
            concave_count += 1
        print()

#     if concave_count >= convex_count:
#         return "concave"
#     else:
#         return "convex"

a = [5345.999999999996, 4909.904334989346, 4780.844136675267, 4743.852776203679, 4735.169650536558, 4081.0340751505682, 1985.9894627564358, 1683.6842207926986, 1401.4090593157669, 1237.7644835798549, 1129.9284793236557]

__determine_curve(a)
