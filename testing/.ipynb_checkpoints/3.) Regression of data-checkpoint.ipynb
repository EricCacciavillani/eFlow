# %% [markdown]
# Find the markdown blocks that say interaction required! The notebook should take care of the rest!

# %% [markdown]
# # Import libs

# %%
import sys
import os
sys.path.append('..')
from eflow.foundation import DataPipeline,DataFrameTypes
from eflow.model_analysis import RegressionAnalysis
from eflow.utils.modeling_utils import optimize_model_grid
from eflow.utils.eflow_utils import get_type_holder_from_pipeline, remove_unconnected_pipeline_segments
from eflow.utils.pandas_utils import data_types_table

import pandas as pd
import numpy as np
import scikitplot as skplt
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
import copy
from IPython.display import clear_output

# %%
# # Additional add ons
# !pip install pandasgui
# !pip install pivottablejs
# clear_output()

# %%
# %matplotlib notebook
# %matplotlib inline

# %% [markdown]
# ## Declare Project Variables

# %% [markdown]
# ### Interaction required

# %%
dataset_path = "Datasets/titanic_train.csv"

# -----
dataset_name = "Titanic Data"
pipeline_name = "Titanic Pipeline"

# -----


# -----
notebook_mode = True

# %% [markdown]
# ## Clean out segment space

# %%
remove_unconnected_pipeline_segments()

# %% [markdown]
# # Import dataset

# %%
df = pd.read_csv(dataset_path)
shape_df = pd.DataFrame.from_dict({'Rows': [df.shape[0]],
                                   'Columns': [df.shape[1]]})
display(shape_df)
display(df.head(30))
# Out:
#    Rows  Columns
# 0   891       12
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# 26           27         0       3
# 27           28         0       1
# 28           29         1       3
# 29           30         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                               Rice, Master. Eugene    male   2.0      4
# 17                       Williams, Mr. Charles Eugene    male   NaN      0
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                            Masselmani, Mrs. Fatima  female   NaN      0
# 20                               Fynney, Mr. Joseph J    male  35.0      0
# 21                              Beesley, Mr. Lawrence    male  34.0      0
# 22                        McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
# 24                      Palsson, Miss. Torborg Danira  female   8.0      3
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 26                            Emir, Mr. Farred Chehab    male   NaN      0
# 27                     Fortune, Mr. Charles Alexander    male  19.0      3
# 28                      O'Dwyer, Miss. Ellen "Nellie"  female   NaN      0
# 29                                Todoroff, Mr. Lalio    male   NaN      0
#
#     Parch            Ticket      Fare        Cabin Embarked
# 0       0         A/5 21171    7.2500          NaN        S
# 1       0          PC 17599   71.2833          C85        C
# 2       0  STON/O2. 3101282    7.9250          NaN        S
# 3       0            113803   53.1000         C123        S
# 4       0            373450    8.0500          NaN        S
# 5       0            330877    8.4583          NaN        Q
# 6       0             17463   51.8625          E46        S
# 7       1            349909   21.0750          NaN        S
# 8       2            347742   11.1333          NaN        S
# 9       0            237736   30.0708          NaN        C
# 10      1           PP 9549   16.7000           G6        S
# 11      0            113783   26.5500         C103        S
# 12      0         A/5. 2151    8.0500          NaN        S
# 13      5            347082   31.2750          NaN        S
# 14      0            350406    7.8542          NaN        S
# 15      0            248706   16.0000          NaN        S
# 16      1            382652   29.1250          NaN        Q
# 17      0            244373   13.0000          NaN        S
# 18      0            345763   18.0000          NaN        S
# 19      0              2649    7.2250          NaN        C
# 20      0            239865   26.0000          NaN        S
# 21      0            248698   13.0000          D56        S
# 22      0            330923    8.0292          NaN        Q
# 23      0            113788   35.5000           A6        S
# 24      1            349909   21.0750          NaN        S
# 25      5            347077   31.3875          NaN        S
# 26      0              2631    7.2250          NaN        C
# 27      2             19950  263.0000  C23 C25 C27        S
# 28      0            330959    7.8792          NaN        Q
# 29      0            349216    7.8958          NaN        S

# %%
data_types_table(df)
# Out:
#             Data Types
# Features
# Age            float64
# Fare           float64
# PassengerId      int64
# Survived         int64
# Pclass           int64
# SibSp            int64
# Parch            int64
# Name            object
# Sex             object
# Ticket          object
# Cabin           object
# Embarked        object

# %% [markdown]
# # Loading and init df_features

# %%
# Option: 1
# df_features = get_type_holder_from_pipeline(pipeline_name)

# %%
# Option: 2
df_features = DataFrameTypes()
df_features.init_on_json_file(os.getcwd() + f"/eflow Data/{dataset_name}/df_features.json")

# %%
df_features.display_features(display_dataframes=True,
                             notebook_mode=notebook_mode)
# Out:
#          Data Types
# Features
# Sex          string
# Pclass       string
# Cabin        string
# Embarked     string
# Survived       bool
# Parch       integer
# SibSp       integer
# Age           float
# Fare          float

# %% [markdown]
# # Any extra processing before eflow DataPipeline

# %% [markdown]
# # Setup pipeline structure

# %% [markdown]
# ### Interaction Required

# %%
main_pipe = DataPipeline(pipeline_name,
                         df,
                         df_features)
# Out:
# The file 'root_pipeline.json' exist!
# Now configuring object with proper pipeline segments...
# Removing the feature: "Ticket"
# Removing the feature: "Name"
# Removing the feature: "PassengerId"

# %%
main_pipe.perform_pipeline(df,
                           df_features)
# Out:
# Ignore feature:  Fare

# %%
df
# Out:
#      Survived        Age  SibSp  Parch      Fare  Sex_female  Sex_male  \
# 0           0  22.000000      1      0    7.2500       False      True
# 1           1  38.000000      1      0   71.2833        True     False
# 2           1  26.000000      0      0    7.9250        True     False
# 3           1  35.000000      1      0   53.1000        True     False
# 4           0  35.000000      0      0    8.0500       False      True
# 5           0  29.444268      0      0    8.4583       False      True
# 6           0  54.000000      0      0   51.8625       False      True
# 7           0   2.000000      3      1   21.0750       False      True
# 8           1  27.000000      0      2   11.1333        True     False
# 9           1  14.000000      1      0   30.0708        True     False
# 10          1   4.000000      1      1   16.7000        True     False
# 11          1  58.000000      0      0   26.5500        True     False
# 12          0  20.000000      0      0    8.0500       False      True
# 13          0  39.000000      1      5   31.2750       False      True
# 14          0  14.000000      0      0    7.8542        True     False
# 15          1  55.000000      0      0   16.0000        True     False
# 16          0   2.000000      4      1   29.1250       False      True
# 17          1  29.444268      0      0   13.0000       False      True
# 873     False     False      True               False                False
# 874     False      True     False                True                False
# 875     False     False      True                True                False
# 876     False     False      True               False                False
# 877     False     False      True               False                False
# 878     False     False      True               False                False
# 879      True     False     False                True                False
# 880     False      True     False               False                False
# 881     False     False      True               False                False
# 882     False     False      True               False                False
# 883     False      True     False               False                False
# 884     False     False      True               False                False
# 885     False     False      True               False                 True
# 886     False      True     False               False                False
# 887      True     False     False               False                False
# 888     False     False      True               False                False
# 889      True     False     False                True                False
# 890     False     False      True               False                 True
#
#      Embarked_Southampton
# 0                    True
# 1                   False
# 2                    True
# 3                    True
# 4                    True
# 5                   False
# 6                    True
# 7                    True
# 8                    True
# 9                   False
# 10                   True
# 11                   True
# 12                   True
# 13                   True
# 14                   True
# 15                   True
# 16                  False
# 17                   True
# 18                   True
# 19                  False
# 20                   True
# 21                   True
# 22                  False
# 23                   True
# 24                   True
# 25                   True
# 26                  False
# 27                   True
# 28                  False
# 29                   True
# ..                    ...
# 861                  True
# 862                  True
# 863                  True
# 864                  True
# 865                  True
# 866                 False
# 867                  True
# 868                  True
# 869                  True
# 870                  True
# 871                  True
# 872                  True
# 873                  True
# 874                 False
# 875                 False
# 876                  True
# 877                  True
# 878                  True
# 879                 False
# 880                  True
# 881                  True
# 882                  True
# 883                  True
# 884                  True
# 885                 False
# 886                  True
# 887                  True
# 888                  True
# 889                 False
# 890                 False
#
# [891 rows x 13 columns]

# %% [markdown]
# # Seperate out data into train and test sets

# %%
X = df.drop(columns="Age").values
y = df["Age"].values

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=517,
)

# %%
feature_order = list(df.columns)

# %%
del df

# %% [markdown]
# # Fit Models and view results

# %%
# Find best parameters for model
param_grid = {
    "max_depth": list(range(1, 4)),
#     "min_samples_leaf": list(range(80, 130, 5)),
#     "criterion": ["gini", "entropy"],
#     "n_splits": [20, 30]
}

model, best_params = optimize_model_grid(
    model=DecisionTreeRegressor(),
    X_train=X_train,
    y_train=y_train,
    param_grid=param_grid,
    scoring="r2"
)
# Out:
# Tuned Parameters: {'max_depth': 3}
# Best score on trained data was 0.132777
# /Users/ericcacciavillani/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %%
model.fit(X,y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=3, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
model_name = repr(model).split("(")[0]

# %%
from sklearn.metrics import r2_score, explained_variance_score, mean_absolute_error, mean_squared_error, mean_squared_log_error, median_absolute_error
r2_score(y,y)
median_absolute_error(model.predict(X_train),y_train)
explained_variance_score(model.predict(X_train),y_train)
# Out:
# 7.392526830119547

# %%
model_analysis = RegressionAnalysis(dataset_name=dataset_name,
                                    model=model,
                                    model_name=model_name,
                                    feature_order=feature_order,
                                    target_feature=df_features.target_feature(),
                                    pred_funcs_dict={"Predict function":model.predict},
                                    sample_data=X_train[0],
                                    notebook_mode=notebook_mode,
                                    df_features=df_features)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-6833524b794a> in <module>
#       7                                     sample_data=X_train[0],
#       8                                     notebook_mode=notebook_mode,
# ----> 9                                     df_features=df_features)
#
# TypeError: __init__() got an unexpected keyword argument 'pred_funcs_dict'

# %%
model_analysis.perform_analysis(X=X_train,
                                y=y_train,
                                dataset_name="Train Data",
                                thresholds_matrix=[[.0,.0],
                                                   [.12,.04]],
                                classification_error_analysis=True,
                                classification_correct_analysis=True)

# %%
# model_analysis.perform_analysis(X=X_test,
#                                 y=y_test,
#                                 dataset_name="Test Data",
#                                 thresholds_matrix=[[.0,.0],
#                                                    [.12,.04]],
#                                 classification_error_analysis=True,
#                                 classification_correct_analysis=True)
